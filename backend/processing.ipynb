# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv(r"C:\Users\rahul\Desktop\Offshore\PubSec-Info-Assistant-Offshore\PubSec-Info-Assistant-Offshore-1\backend\df_english_v2.csv")
df.head()
# Out:
#   Apartment_code  project_id                                Project URL  \
# 0         A00001          77  https://sakani.sa/app/offplan-projects/77
# 1         A00002          77  https://sakani.sa/app/offplan-projects/77
# 2         A00003          77  https://sakani.sa/app/offplan-projects/77
# 3         A00004          77  https://sakani.sa/app/offplan-projects/77
# 4         A00005          77  https://sakani.sa/app/offplan-projects/77
#
#                      project_name_eng city_id_eng region_id_eng  \
# 0  Tabuk - Modern houses - Dora Tabuk       Tabuk         Tabuk
# 1  Tabuk - Modern houses - Dora Tabuk       Tabuk         Tabuk
# 2  Tabuk - Modern houses - Dora Tabuk       Tabuk         Tabuk
# 3  Tabuk - Modern houses - Dora Tabuk       Tabuk         Tabuk
# 4  Tabuk - Modern houses - Dora Tabuk       Tabuk         Tabuk
#
#   District_Residential_area_eng  allow_payment_by_cash  allow_payment_by_loan  \
# ...

# %%
df.isnull().sum()
# Out:
# Apartment_code                            0
# project_id                                0
# Project URL                               0
# project_name_eng                          0
# city_id_eng                               0
# region_id_eng                             0
# District_Residential_area_eng             0
# allow_payment_by_cash                     0
# allow_payment_by_loan                     0
# project_latitude                          0
# project_longitude                         0
# publish_date                              0
# Construction_Completion_Percentage        0
# sakani_beneficiary_price                  0
# non_sakani_beneficiary_price              0
# apatment_area_meter                       0
# living_area                               0
# floor                                     0
# bathroom_count                            0
# apartment_type_eng                        0
# number_of_rooms                         704
# ...

# %%
df.fillna(0.0, axis=1, inplace=True)
df.isnull().sum().sum()
# Out:
# 0

# %%
df.to_csv(r"C:\Users\rahul\Desktop\Offshore\PubSec-Info-Assistant-Offshore\PubSec-Info-Assistant-Offshore-1\backend\df_english_v2.csv", index=False)
